# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
print (titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
titanic.tail(20)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 871         1       1  female  47.0      1      1  52.5542        S    D
# 872         0       1    male  33.0      0      0   5.0000        S    B
# 873         0       3    male  47.0      0      0   9.0000        S  NaN
# 874         1       2  female  28.0      1      0  24.0000        C  NaN
# 875         1       3  female  15.0      0      0   7.2250        C  NaN
# 876         0       3    male  20.0      0      0   9.8458        S  NaN
# 877         0       3    male  19.0      0      0   7.8958        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# ...

# %% [markdown]
# # inspecting a dataset

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include = "O")
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# # Built in functions and dataframes

# %%
type (titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
len (titanic)
# Out:
# 891

# %%
int (titanic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-057dfdef8c2f> in <module>
# ----> 1 int (titanic)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'DataFrame'

# %%
min(titanic)
# Out:
# 'age'

# %% [markdown]
# ##### Dataframe ATTRIBUTES

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.size
# Out:
# 8019

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %% [markdown]
# #### Dataframe methods

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.min()
# Out:
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare             0
# dtype: object

# %% [markdown]
# #### Method Chaining

# %%
titanic.mean()
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic.mean().sort_values()
# Out:
# parch        0.381594
# survived     0.383838
# sibsp        0.523008
# pclass       2.308642
# age         29.699118
# fare        32.204208
# dtype: float64

# %%
titanic.mean().sort_values().head(2)
# Out:
# parch       0.381594
# survived    0.383838
# dtype: float64

# %% [markdown]
# ###### TAB COMPLETION AND TOOL TIP

# %%
import pandas as pd

# %%
pd.read_csv("titanic.csv")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic = pd.read_csv ("titanic.csv")

# %%
titanic.sort_values(by="age", ascending= False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 851         0       3    male  74.0      0      0   7.7750        S  NaN
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 116         0       3    male  70.5      0      0   7.7500        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %% [markdown]
# ## SELECTING COLUMNS

# %%
titanic ["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(titanic["age"])
# Out:
# pandas.core.series.Series

# %%
titanic[["age", "sex"]]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(titanic[["age", "sex"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic[["sex", "age"]]
# Out:
#         sex   age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
titanic[["sex", "age", "fare"]]
# Out:
#         sex   age     fare
# 0      male  22.0   7.2500
# 1    female  38.0  71.2833
# 2    female  26.0   7.9250
# 3    female  35.0  53.1000
# 4      male  35.0   8.0500
# ..      ...   ...      ...
# 886    male  27.0  13.0000
# 887  female  19.0  30.0000
# 888  female   NaN  23.4500
# 889    male  26.0  30.0000
# 890    male  32.0   7.7500
#
# [891 rows x 3 columns]

# %% [markdown]
# ### Selecting one column with 'dot notation'

# %%
titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.age.equals(titanic["age"])
# Out:
# True

# %%
summer = pd.read_csv("summer.csv")

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer = pd.read_csv("summer.csv", index_col = "Athlete")

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# ### selecting rows with iloc [ ]

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
type(summer.iloc[0])
# Out:
# pandas.core.series.Series

# %%
summer.iloc[1]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  AUT
# Gender                   Men
# Event         100M Freestyle
# Medal                 Silver
# Name: HERSCHMANN, Otto, dtype: object

# %%
summer.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
summer.iloc[[1,2,3]]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
summer.iloc[1:4]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
summer.iloc[0:5]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.iloc[:5]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.iloc[-6:]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# GAJIYEV, Danyal            2012  London  Wrestling  Wrestling Freestyle
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender     Event   Medal
# Athlete
# GAJIYEV, Danyal               KAZ    Men  Wg 84 KG  Bronze
# JANIKOWSKI, Damian            POL    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy                SWE    Men  Wg 96 KG  Bronze

# %%
summer.iloc[:]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.iloc[[2, 55, 6670]]
# Out:
#                    Year    City     Sport     Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios  1896  Athens  Aquatics       Swimming     GRE    Men
# FLAMENG, Léon      1896  Athens   Cycling  Cycling Track     FRA    Men
# GENTILI, Mario     1936  Berlin   Cycling  Cycling Track     ITA    Men
#
#                                         Event   Medal
# Athlete
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze
# FLAMENG, Léon                            10KM  Silver
# GENTILI, Mario           Team Pursuit (4000M)  Silver

# %% [markdown]
# ##### Slicing rows and columns

# %%
summer.iloc[0,4]
# Out:
# 'HUN'

# %%
summer.iloc[0,:3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[0,[3]]
# Out:
# Discipline    Swimming
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[0,[0,2,3,5,7]]
# Out:
# Year              1896
# Sport         Aquatics
# Discipline    Swimming
# Gender             Men
# Medal             Gold
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[34:39,[0,2,3,5,7]]
# Out:
#                       Year      Sport Discipline Gender   Medal
# Athlete
# GARRETT, Robert       1896  Athletics  Athletics    Men  Silver
# KELLNER, Gyula        1896  Athletics  Athletics    Men  Bronze
# LOUIS, Spyridon       1896  Athletics  Athletics    Men    Gold
# VASILAKOS, Kharilaos  1896  Athletics  Athletics    Men  Silver
# DAMASKOS, Evangelos   1896  Athletics  Athletics    Men  Bronze

# %% [markdown]
# ### selecting columns with iloc

# %%
summer.iloc[:,4]
# Out:
# Athlete
# HAJOS, Alfred                HUN
# HERSCHMANN, Otto             AUT
# DRIVAS, Dimitrios            GRE
# MALOKINIS, Ioannis           GRE
# CHASAPIS, Spiridon           GRE
#                             ...
# JANIKOWSKI, Damian           POL
# REZAEI, Ghasem Gholamreza    IRI
# TOTROV, Rustam               RUS
# ALEKSANYAN, Artur            ARM
# LIDBERG, Jimmy               SWE
# Name: Country, Length: 31165, dtype: object

# %%
summer.iloc[:,4].equals (summer.Country)
# Out:
# True

# %% [markdown]
# ## label based indexing

# %%
summer.iloc[2]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc["VASILAKOS, Kharilaos"]
# Out:
# Year               1896
# City             Athens
# Sport         Athletics
# Discipline    Athletics
# Country             GRE
# Gender              Men
# Event          Marathon
# Medal            Silver
# Name: VASILAKOS, Kharilaos, dtype: object

# %%
summer.loc["PHELPS, Michael"]
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %%
summer.loc[:, ["PHELPS, Michael"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-fd89a427c004> in <module>
# ----> 1 summer.loc[:, ["PHELPS, Michael"]]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %% [markdown]
# ### Indexing and slicing with reindex ()

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.loc[[0,5,30000], ["Athlete", "Medal"]]
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze

# %%
summer = pd.read_csv("summer.csv")

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# ##### indexing and slicing with reindex

# %%
summer.loc[[0,5, 30000],["Athlete", "Medal"]]
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze

# %%
summer.reindex (index= [0,5, 30000,40000],columns = ["Athlete", "Medal"])
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze
# 40000                    NaN     NaN

# %% [markdown]
# ## selecting one column

# %%
summer.Medal
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3          Gold
# 4        Silver
#           ...
# 31160    Bronze
# 31161      Gold
# 31162    Silver
# 31163    Bronze
# 31164    Bronze
# Name: Medal, Length: 31165, dtype: object

# %%
summer["Medal"]
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3          Gold
# 4        Silver
#           ...
# 31160    Bronze
# 31161      Gold
# 31162    Silver
# 31163    Bronze
# 31164    Bronze
# Name: Medal, Length: 31165, dtype: object

# %% [markdown]
# ### Selecting multiple columns

# %%
summer[["Year", "Medal"]]
# Out:
#        Year   Medal
# 0      1896    Gold
# 1      1896  Silver
# 2      1896  Bronze
# 3      1896    Gold
# 4      1896  Silver
# ...     ...     ...
# 31160  2012  Bronze
# 31161  2012    Gold
# 31162  2012  Silver
# 31163  2012  Bronze
# 31164  2012  Bronze
#
# [31165 rows x 2 columns]

# %%
summer.loc[:,["Year", "Medal"]]
# Out:
#        Year   Medal
# 0      1896    Gold
# 1      1896  Silver
# 2      1896  Bronze
# 3      1896    Gold
# 4      1896  Silver
# ...     ...     ...
# 31160  2012  Bronze
# 31161  2012    Gold
# 31162  2012  Silver
# 31163  2012  Bronze
# 31164  2012  Bronze
#
# [31165 rows x 2 columns]

# %% [markdown]
# ## selecting positional rows

# %%
summer.iloc[10:21]
# Out:
#     Year    City      Sport Discipline             Athlete Country Gender  \
# 10  1896  Athens   Aquatics   Swimming   PEPANOS, Antonios     GRE    Men
# 11  1896  Athens  Athletics  Athletics       LANE, Francis     USA    Men
# 12  1896  Athens  Athletics  Athletics    SZOKOLYI, Alajos     HUN    Men
# 13  1896  Athens  Athletics  Athletics       BURKE, Thomas     USA    Men
# 14  1896  Athens  Athletics  Athletics      HOFMANN, Fritz     GER    Men
# 15  1896  Athens  Athletics  Athletics      CURTIS, Thomas     USA    Men
# 16  1896  Athens  Athletics  Athletics  GOULDING, Grantley     GBR    Men
# 17  1896  Athens  Athletics  Athletics   LERMUSIAUX, Albin     FRA    Men
# 18  1896  Athens  Athletics  Athletics        FLACK, Edwin     AUS    Men
# 19  1896  Athens  Athletics  Athletics       BLAKE, Arthur     USA    Men
# 20  1896  Athens  Athletics  Athletics     GMELIN, Charles     GBR    Men
#
#              Event   Medal
# 10  400M Freestyle  Silver
# ...

# %% [markdown]
# ##### selecting labeled rows

# %%
summer1.loc["HAJOS, Alfred"]
# Out:
#                Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
#
#                          Event Medal
# Athlete
# HAJOS, Alfred   100M Freestyle  Gold
# HAJOS, Alfred  1200M Freestyle  Gold

# %%
summer1 = pd.read_csv("summer.csv", index_col = "Athlete")

# %% [markdown]
# ## putting it together

# %%
summer1[["Year", "Event", "Medal"]].loc["LEWIS, Carl"]
# Out:
#              Year         Event   Medal
# Athlete
# LEWIS, Carl  1984          100M    Gold
# LEWIS, Carl  1984          200M    Gold
# LEWIS, Carl  1984  4X100M Relay    Gold
# LEWIS, Carl  1984     Long Jump    Gold
# LEWIS, Carl  1988          100M    Gold
# LEWIS, Carl  1988          200M  Silver
# LEWIS, Carl  1988     Long Jump    Gold
# LEWIS, Carl  1992  4X100M Relay    Gold
# LEWIS, Carl  1992     Long Jump    Gold
# LEWIS, Carl  1996     Long Jump    Gold

# %%
summer1.loc["LEWIS, Carl"][["Year", "Event", "Medal"]]
# Out:
#              Year         Event   Medal
# Athlete
# LEWIS, Carl  1984          100M    Gold
# LEWIS, Carl  1984          200M    Gold
# LEWIS, Carl  1984  4X100M Relay    Gold
# LEWIS, Carl  1984     Long Jump    Gold
# LEWIS, Carl  1988          100M    Gold
# LEWIS, Carl  1988          200M  Silver
# LEWIS, Carl  1988     Long Jump    Gold
# LEWIS, Carl  1992  4X100M Relay    Gold
# LEWIS, Carl  1992     Long Jump    Gold
# LEWIS, Carl  1996     Long Jump    Gold

# %% [markdown]
# ### Outlook pandas object

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
type(summer)
# Out:
# pandas.core.frame.DataFrame

# %%
summer["Year"]
# Out:
# 0        1896
# 1        1896
# 2        1896
# 3        1896
# 4        1896
#          ...
# 31160    2012
# 31161    2012
# 31162    2012
# 31163    2012
# 31164    2012
# Name: Year, Length: 31165, dtype: int64

# %%
type(summer["Year"])
# Out:
# pandas.core.series.Series

# %%
summer.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender',
#        'Event', 'Medal'],
#       dtype='object')

# %%
type(summer.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
summer.index
# Out:
# RangeIndex(start=0, stop=31165, step=1)

# %%
type(summer.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# # Advanced indexing and slicing

# %% [markdown]
# #### Getting the first 5 rows and row 354 and 765

# %%
row = list (range (5)) + [354, 756]

# %%
row
# Out:
# [0, 1, 2, 3, 4, 354, 756]

# %%
summer.iloc[row]
# Out:
#      Year      City       Sport Discipline             Athlete Country Gender  \
# 0    1896    Athens    Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1    1896    Athens    Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2    1896    Athens    Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3    1896    Athens    Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4    1896    Athens    Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
# 354  1900     Paris  Equestrian    Jumping       DE BELLEGARDE     FRA    Men
# 756  1904  St Louis   Athletics  Athletics       WALLER, Frank     USA    Men
#
#                           Event   Medal
# 0                100M Freestyle    Gold
# 1                100M Freestyle  Silver
# 2    100M Freestyle For Sailors  Bronze
# 3    100M Freestyle For Sailors    Gold
# 4    100M Freestyle For Sailors  Silver
# 354        Long Jump Individual  Bronze
# 756                        400M  Silver

# %% [markdown]
# #### Getting the first three columns and the columns 'gender' and 'event'

# %%
summer.columns [:3].to_list() + ["Gender", "Event"]
# Out:
# ['Year', 'City', 'Sport', 'Gender', 'Event']

# %%
col = summer.columns [:3].to_list() + ["Gender", "Event"]

# %%
col
# Out:
# ['Year', 'City', 'Sport', 'Gender', 'Event']

# %%
summer.loc [:, col]
# Out:
#        Year    City      Sport Gender                       Event
# 0      1896  Athens   Aquatics    Men              100M Freestyle
# 1      1896  Athens   Aquatics    Men              100M Freestyle
# 2      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# 3      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# 4      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# ...     ...     ...        ...    ...                         ...
# 31160  2012  London  Wrestling    Men                    Wg 84 KG
# 31161  2012  London  Wrestling    Men                    Wg 96 KG
# 31162  2012  London  Wrestling    Men                    Wg 96 KG
# 31163  2012  London  Wrestling    Men                    Wg 96 KG
# 31164  2012  London  Wrestling    Men                    Wg 96 KG
#
# [31165 rows x 5 columns]

# %% [markdown]
# ### Combining position and label based indexing: Rows at position 200 and 300 and columns "Athlete" and "Medal".

# %%
summer1
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.loc[[200, 300], ["Athlete", "Medal"]]
# Out:
#                       Athlete   Medal
# 200               KEMP, Peter    Gold
# 300  SHELDON, Lewis Pendleton  Bronze

# %% [markdown]
# ### Combining position and label indexing : Rows "PHELPS, Micheal" and positional column 4 and 6

# %%
summer1.loc["PHELPS, Michael", col]
# Out:
#                  Year     City     Sport Gender                   Event
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics    Men          100M Butterfly
# PHELPS, Michael  2004   Athens  Aquatics    Men          200M Butterfly
# PHELPS, Michael  2004   Athens  Aquatics    Men          200M Freestyle
# PHELPS, Michael  2004   Athens  Aquatics    Men  200M Individual Medley
# PHELPS, Michael  2004   Athens  Aquatics    Men  400M Individual Medley
# PHELPS, Michael  2004   Athens  Aquatics    Men  4X100M Freestyle Relay
# PHELPS, Michael  2004   Athens  Aquatics    Men     4X100M Medley Relay
# PHELPS, Michael  2004   Athens  Aquatics    Men  4X200M Freestyle Relay
# PHELPS, Michael  2008  Beijing  Aquatics    Men          100M Butterfly
# PHELPS, Michael  2008  Beijing  Aquatics    Men          200M Butterfly
# PHELPS, Michael  2008  Beijing  Aquatics    Men          200M Freestyle
# PHELPS, Michael  2008  Beijing  Aquatics    Men  200M Individual Medley
# ...

# %%
summer1.ix["PHELPS, Michael", [4,6]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-189-13f49e0912c1> in <module>
# ----> 1 summer1.ix["PHELPS, Michael", [4,6]]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
